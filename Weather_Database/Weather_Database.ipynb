# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import requests
import time
from datetime import datetime
from config import weather_api_key

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.0, 90.0, size=2000)
lngs = np.random.uniform(-180.0, 180.0, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = list()

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
######## USED https://github.com/wingchen/citipy ##########    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"'There are {len(cities)} cities in this list and here are a some of them: {cities[:5]}")
# Out:
# 'There are 764 cities in this list and here are a some of them: ['pacific grove', 'freeport', 'mataura', 'kapaa', 'busselton']

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
## Moved imports inline with other dependencies for cleaner, easier to read code..

# %%
# Assemble the OpenWeatherMap's API call
url = 'https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid='+ weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather['weather'][0]['description']      
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":description })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pacific grove
# Processing Record 2 of Set 1 | freeport
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | adrar
# Processing Record 7 of Set 1 | ola
# Processing Record 8 of Set 1 | zhob
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | hasaki
# Processing Record 11 of Set 1 | eureka
# Processing Record 12 of Set 1 | aurora
# Processing Record 13 of Set 1 | severo-kurilsk
# Processing Record 14 of Set 1 | te anau
# Processing Record 15 of Set 1 | arraial do cabo
# Processing Record 16 of Set 1 | tuktoyaktuk
# Processing Record 17 of Set 1 | lebu
# Processing Record 18 of Set 1 | port blair
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 1 | khudumelapye
# Processing Record 23 of Set 1 | leningradskiy
# Processing Record 24 of Set 1 | marsh harbour
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | khatanga
# Processing Record 27 of Set 1 | nemuro
# Processing Record 28 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | cabo san lucas
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | cockburn harbour
# City not found. Skipping...
# Processing Record 33 of Set 1 | puerto carreno
# Processing Record 34 of Set 1 | moranbah
# Processing Record 35 of Set 1 | asau
# Processing Record 36 of Set 1 | barrow
# Processing Record 37 of Set 1 | katha
# City not found. Skipping...
# Processing Record 38 of Set 1 | laguna
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | ribeira grande
# Processing Record 42 of Set 1 | lusambo
# Processing Record 43 of Set 1 | bintulu
# Processing Record 44 of Set 1 | bethel
# Processing Record 45 of Set 1 | sug-aksy
# City not found. Skipping...
# Processing Record 46 of Set 1 | namibe
# Processing Record 47 of Set 1 | jumla
# Processing Record 48 of Set 1 | cayenne
# Processing Record 49 of Set 1 | atuona
# Processing Record 50 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 2 | hanford
# Processing Record 2 of Set 2 | tonantins
# Processing Record 3 of Set 2 | geraldton
# Processing Record 4 of Set 2 | olafsvik
# Processing Record 5 of Set 2 | saint george
# Processing Record 6 of Set 2 | victoria
# Processing Record 7 of Set 2 | hobart
# Processing Record 8 of Set 2 | mehamn
# Processing Record 9 of Set 2 | sangar
# Processing Record 10 of Set 2 | yellowknife
# Processing Record 11 of Set 2 | rikitea
# Processing Record 12 of Set 2 | sitka
# Processing Record 13 of Set 2 | vega de alatorre
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | hassleholm
# Processing Record 16 of Set 2 | bradford
# Processing Record 17 of Set 2 | qaanaaq
# Processing Record 18 of Set 2 | tuatapere
# Processing Record 19 of Set 2 | esperance
# Processing Record 20 of Set 2 | pocoes
# Processing Record 21 of Set 2 | bogo
# Processing Record 22 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 2 | portland
# Processing Record 24 of Set 2 | qasigiannguit
# Processing Record 25 of Set 2 | clyde river
# Processing Record 26 of Set 2 | katsuura
# Processing Record 27 of Set 2 | chas
# Processing Record 28 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 29 of Set 2 | kaitangata
# Processing Record 30 of Set 2 | la sarre
# Processing Record 31 of Set 2 | morro bay
# Processing Record 32 of Set 2 | harpanahalli
# Processing Record 33 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 2 | fairbanks
# Processing Record 35 of Set 2 | san cristobal
# Processing Record 36 of Set 2 | general pico
# Processing Record 37 of Set 2 | hermanus
# Processing Record 38 of Set 2 | mount isa
# Processing Record 39 of Set 2 | lavrentiya
# Processing Record 40 of Set 2 | rafraf
# Processing Record 41 of Set 2 | muncar
# Processing Record 42 of Set 2 | kostyantynivka
# Processing Record 43 of Set 2 | mgandu
# Processing Record 44 of Set 2 | jutai
# Processing Record 45 of Set 2 | sidi ali
# Processing Record 46 of Set 2 | bilma
# Processing Record 47 of Set 2 | upernavik
# Processing Record 48 of Set 2 | kargasok
# Processing Record 49 of Set 2 | dunmore east
# Processing Record 50 of Set 2 | bandarbeyla
# Processing Record 1 of Set 3 | praia da vitoria
# Processing Record 2 of Set 3 | thompson
# Processing Record 3 of Set 3 | manta
# Processing Record 4 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 5 of Set 3 | bengkulu
# Processing Record 6 of Set 3 | hirara
# Processing Record 7 of Set 3 | nikolskoye
# Processing Record 8 of Set 3 | kodiak
# Processing Record 9 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 3 | bambous virieux
# Processing Record 11 of Set 3 | matiri
# Processing Record 12 of Set 3 | provideniya
# Processing Record 13 of Set 3 | andenes
# Processing Record 14 of Set 3 | hilo
# Processing Record 15 of Set 3 | tondano
# Processing Record 16 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 3 | norman wells
# Processing Record 19 of Set 3 | castro
# Processing Record 20 of Set 3 | cidreira
# Processing Record 21 of Set 3 | galesong
# Processing Record 22 of Set 3 | coihaique
# Processing Record 23 of Set 3 | port elizabeth
# Processing Record 24 of Set 3 | tasiilaq
# Processing Record 25 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 3 | ciudad bolivar
# Processing Record 27 of Set 3 | olga
# Processing Record 28 of Set 3 | ostrovnoy
# Processing Record 29 of Set 3 | ji-parana
# City not found. Skipping...
# Processing Record 30 of Set 3 | torbay
# Processing Record 31 of Set 3 | husavik
# Processing Record 32 of Set 3 | ponta do sol
# Processing Record 33 of Set 3 | baruun-urt
# Processing Record 34 of Set 3 | pilar
# Processing Record 35 of Set 3 | naryan-mar
# Processing Record 36 of Set 3 | pevek
# Processing Record 37 of Set 3 | mahebourg
# Processing Record 38 of Set 3 | hofn
# Processing Record 39 of Set 3 | anchorage
# Processing Record 40 of Set 3 | mecca
# Processing Record 41 of Set 3 | yueyang
# Processing Record 42 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 3 | mar del plata
# Processing Record 44 of Set 3 | atar
# Processing Record 45 of Set 3 | nuuk
# Processing Record 46 of Set 3 | lompoc
# Processing Record 47 of Set 3 | touros
# Processing Record 48 of Set 3 | tautira
# Processing Record 49 of Set 3 | vao
# Processing Record 50 of Set 3 | mbini
# Processing Record 1 of Set 4 | lorengau
# Processing Record 2 of Set 4 | cape town
# Processing Record 3 of Set 4 | hamilton
# Processing Record 4 of Set 4 | pamplona
# Processing Record 5 of Set 4 | srednekolymsk
# Processing Record 6 of Set 4 | troitsko-pechorsk
# Processing Record 7 of Set 4 | mezhdurechensk
# Processing Record 8 of Set 4 | lagoa
# Processing Record 9 of Set 4 | san carlos de bariloche
# Processing Record 10 of Set 4 | saldanha
# Processing Record 11 of Set 4 | broken hill
# Processing Record 12 of Set 4 | biskamzha
# Processing Record 13 of Set 4 | arnsberg
# Processing Record 14 of Set 4 | samarai
# Processing Record 15 of Set 4 | tommot
# Processing Record 16 of Set 4 | korla
# Processing Record 17 of Set 4 | georgetown
# Processing Record 18 of Set 4 | kavieng
# Processing Record 19 of Set 4 | gat
# Processing Record 20 of Set 4 | celendin
# Processing Record 21 of Set 4 | albany
# Processing Record 22 of Set 4 | port-gentil
# Processing Record 23 of Set 4 | karratha
# Processing Record 24 of Set 4 | pangnirtung
# Processing Record 25 of Set 4 | leeton
# Processing Record 26 of Set 4 | atambua
# Processing Record 27 of Set 4 | yataity
# Processing Record 28 of Set 4 | dikson
# Processing Record 29 of Set 4 | constitucion
# Processing Record 30 of Set 4 | ambulu
# Processing Record 31 of Set 4 | hendijan
# City not found. Skipping...
# Processing Record 32 of Set 4 | sao joao da barra
# Processing Record 33 of Set 4 | marfino
# Processing Record 34 of Set 4 | port alfred
# Processing Record 35 of Set 4 | ilulissat
# Processing Record 36 of Set 4 | ravar
# Processing Record 37 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 4 | chany
# Processing Record 39 of Set 4 | carnarvon
# Processing Record 40 of Set 4 | moose factory
# Processing Record 41 of Set 4 | kyabe
# Processing Record 42 of Set 4 | muravlenko
# Processing Record 43 of Set 4 | oussouye
# Processing Record 44 of Set 4 | black river
# Processing Record 45 of Set 4 | airai
# Processing Record 46 of Set 4 | cururupu
# Processing Record 47 of Set 4 | vila franca do campo
# Processing Record 48 of Set 4 | presidencia roque saenz pena
# Processing Record 49 of Set 4 | chuy
# Processing Record 50 of Set 4 | port hardy
# Processing Record 1 of Set 5 | havre-saint-pierre
# Processing Record 2 of Set 5 | kahului
# Processing Record 3 of Set 5 | riviere-au-renard
# Processing Record 4 of Set 5 | okato
# Processing Record 5 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 6 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 5 | barcelos
# Processing Record 8 of Set 5 | kiama
# Processing Record 9 of Set 5 | grand gaube
# Processing Record 10 of Set 5 | mackenzie
# Processing Record 11 of Set 5 | jamestown
# Processing Record 12 of Set 5 | scarborough
# Processing Record 13 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 5 | port macquarie
# Processing Record 15 of Set 5 | fukue
# Processing Record 16 of Set 5 | natal
# Processing Record 17 of Set 5 | faanui
# Processing Record 18 of Set 5 | bozoum
# Processing Record 19 of Set 5 | faya
# Processing Record 20 of Set 5 | iqaluit
# Processing Record 21 of Set 5 | belmonte
# Processing Record 22 of Set 5 | loreto
# Processing Record 23 of Set 5 | bagdarin
# Processing Record 24 of Set 5 | fortuna
# Processing Record 25 of Set 5 | alofi
# Processing Record 26 of Set 5 | rovinj
# Processing Record 27 of Set 5 | sabara
# Processing Record 28 of Set 5 | new norfolk
# Processing Record 29 of Set 5 | bhag
# Processing Record 30 of Set 5 | porto da folha
# Processing Record 31 of Set 5 | horodnytsya
# Processing Record 32 of Set 5 | shaunavon
# Processing Record 33 of Set 5 | jiayuguan
# Processing Record 34 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 5 | saint anthony
# Processing Record 36 of Set 5 | cape canaveral
# Processing Record 37 of Set 5 | north bend
# Processing Record 38 of Set 5 | kichera
# Processing Record 39 of Set 5 | luancheng
# Processing Record 40 of Set 5 | butaritari
# Processing Record 41 of Set 5 | mabaruma
# Processing Record 42 of Set 5 | east london
# Processing Record 43 of Set 5 | bardiyah
# Processing Record 44 of Set 5 | sudbury
# Processing Record 45 of Set 5 | flinders
# Processing Record 46 of Set 5 | bay roberts
# Processing Record 47 of Set 5 | campoverde
# Processing Record 48 of Set 5 | nosy varika
# Processing Record 49 of Set 5 | gashua
# Processing Record 50 of Set 5 | praxedis guerrero
# Processing Record 1 of Set 6 | ler
# Processing Record 2 of Set 6 | pishin
# Processing Record 3 of Set 6 | el wasta
# City not found. Skipping...
# Processing Record 4 of Set 6 | emiliano zapata
# Processing Record 5 of Set 6 | tutoia
# Processing Record 6 of Set 6 | beitbridge
# Processing Record 7 of Set 6 | saint-philippe
# Processing Record 8 of Set 6 | yermekeyevo
# Processing Record 9 of Set 6 | nanortalik
# Processing Record 10 of Set 6 | lynn haven
# Processing Record 11 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 12 of Set 6 | altar
# Processing Record 13 of Set 6 | chuka
# Processing Record 14 of Set 6 | tokur
# Processing Record 15 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 6 | waddan
# Processing Record 17 of Set 6 | urdoma
# Processing Record 18 of Set 6 | sao filipe
# Processing Record 19 of Set 6 | goderich
# Processing Record 20 of Set 6 | sigiriya
# Processing Record 21 of Set 6 | vostok
# Processing Record 22 of Set 6 | haines junction
# Processing Record 23 of Set 6 | bubaque
# Processing Record 24 of Set 6 | jiangyou
# Processing Record 25 of Set 6 | san patricio
# Processing Record 26 of Set 6 | toulepleu
# City not found. Skipping...
# Processing Record 27 of Set 6 | taksimo
# Processing Record 28 of Set 6 | dingle
# Processing Record 29 of Set 6 | yulara
# Processing Record 30 of Set 6 | honiara
# Processing Record 31 of Set 6 | marawi
# Processing Record 32 of Set 6 | qandala
# Processing Record 33 of Set 6 | palora
# Processing Record 34 of Set 6 | saint-pierre
# Processing Record 35 of Set 6 | yeppoon
# Processing Record 36 of Set 6 | camacha
# Processing Record 37 of Set 6 | eydhafushi
# Processing Record 38 of Set 6 | hirado
# Processing Record 39 of Set 6 | coahuayana
# Processing Record 40 of Set 6 | saint paul
# Processing Record 41 of Set 6 | vila velha
# Processing Record 42 of Set 6 | belaya gora
# Processing Record 43 of Set 6 | sioux lookout
# Processing Record 44 of Set 6 | palestine
# Processing Record 45 of Set 6 | saint-francois
# Processing Record 46 of Set 6 | tiksi
# Processing Record 47 of Set 6 | gualaquiza
# Processing Record 48 of Set 6 | leshukonskoye
# Processing Record 49 of Set 6 | anadyr
# Processing Record 50 of Set 6 | westlock
# Processing Record 1 of Set 7 | esna
# Processing Record 2 of Set 7 | giddarbaha
# Processing Record 3 of Set 7 | russell
# Processing Record 4 of Set 7 | hambantota
# Processing Record 5 of Set 7 | svobodnyy
# Processing Record 6 of Set 7 | acapulco
# Processing Record 7 of Set 7 | dudinka
# Processing Record 8 of Set 7 | harper
# Processing Record 9 of Set 7 | mana
# Processing Record 10 of Set 7 | lethem
# Processing Record 11 of Set 7 | matamoros
# Processing Record 12 of Set 7 | pitimbu
# Processing Record 13 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 7 | iroquois falls
# Processing Record 15 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 16 of Set 7 | parabel
# Processing Record 17 of Set 7 | abu kamal
# Processing Record 18 of Set 7 | boddam
# Processing Record 19 of Set 7 | revda
# Processing Record 20 of Set 7 | shingu
# Processing Record 21 of Set 7 | ostrov
# Processing Record 22 of Set 7 | butia
# Processing Record 23 of Set 7 | minna
# Processing Record 24 of Set 7 | new castle
# Processing Record 25 of Set 7 | bani
# Processing Record 26 of Set 7 | kruisfontein
# Processing Record 27 of Set 7 | kokopo
# Processing Record 28 of Set 7 | hovd
# Processing Record 29 of Set 7 | acari
# Processing Record 30 of Set 7 | segovia
# Processing Record 31 of Set 7 | panlaitan
# Processing Record 32 of Set 7 | stabat
# Processing Record 33 of Set 7 | cascais
# Processing Record 34 of Set 7 | vanimo
# Processing Record 35 of Set 7 | burns lake
# Processing Record 36 of Set 7 | iramuco
# Processing Record 37 of Set 7 | la ronge
# Processing Record 38 of Set 7 | vuktyl
# Processing Record 39 of Set 7 | abu samrah
# Processing Record 40 of Set 7 | isangel
# Processing Record 41 of Set 7 | goias
# Processing Record 42 of Set 7 | ulaangom
# Processing Record 43 of Set 7 | college
# Processing Record 44 of Set 7 | pechenga
# Processing Record 45 of Set 7 | kwale
# Processing Record 46 of Set 7 | stokmarknes
# Processing Record 47 of Set 7 | bismarck
# Processing Record 48 of Set 7 | porto novo
# Processing Record 49 of Set 7 | redwater
# Processing Record 50 of Set 7 | padampur
# Processing Record 1 of Set 8 | talnakh
# Processing Record 2 of Set 8 | velikie luki
# City not found. Skipping...
# Processing Record 3 of Set 8 | karakose
# City not found. Skipping...
# Processing Record 4 of Set 8 | kasongo-lunda
# Processing Record 5 of Set 8 | rocha
# Processing Record 6 of Set 8 | klyuchi
# Processing Record 7 of Set 8 | bestobe
# Processing Record 8 of Set 8 | san quintin
# Processing Record 9 of Set 8 | kirkwood
# Processing Record 10 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 11 of Set 8 | porto velho
# Processing Record 12 of Set 8 | ust-uda
# Processing Record 13 of Set 8 | fuyang
# Processing Record 14 of Set 8 | hami
# Processing Record 15 of Set 8 | crab hill
# City not found. Skipping...
# Processing Record 16 of Set 8 | hun
# Processing Record 17 of Set 8 | rawah
# Processing Record 18 of Set 8 | axim
# Processing Record 19 of Set 8 | brigantine
# Processing Record 20 of Set 8 | saskylakh
# Processing Record 21 of Set 8 | dodge city
# Processing Record 22 of Set 8 | gizo
# Processing Record 23 of Set 8 | kluang
# Processing Record 24 of Set 8 | bokspits
# City not found. Skipping...
# Processing Record 25 of Set 8 | clarence town
# Processing Record 26 of Set 8 | kaeo
# Processing Record 27 of Set 8 | santa maria
# Processing Record 28 of Set 8 | kishtwar
# Processing Record 29 of Set 8 | peniche
# Processing Record 30 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 31 of Set 8 | kletskaya
# Processing Record 32 of Set 8 | richards bay
# Processing Record 33 of Set 8 | caravelas
# Processing Record 34 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 8 | chifeng
# Processing Record 36 of Set 8 | san buenaventura
# Processing Record 37 of Set 8 | kachikau
# City not found. Skipping...
# Processing Record 38 of Set 8 | itoman
# Processing Record 39 of Set 8 | sheridan
# Processing Record 40 of Set 8 | gdov
# Processing Record 41 of Set 8 | katobu
# Processing Record 42 of Set 8 | camana
# Processing Record 43 of Set 8 | burica
# City not found. Skipping...
# Processing Record 44 of Set 8 | viedma
# Processing Record 45 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 8 | polyarnyy
# Processing Record 47 of Set 8 | sarangani
# Processing Record 48 of Set 8 | lodwar
# Processing Record 49 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 8 | chokurdakh
# Processing Record 1 of Set 9 | ocos
# Processing Record 2 of Set 9 | aktau
# Processing Record 3 of Set 9 | plouzane
# Processing Record 4 of Set 9 | yerbogachen
# Processing Record 5 of Set 9 | coxim
# Processing Record 6 of Set 9 | santo antonio do ica
# Processing Record 7 of Set 9 | yeletskiy
# City not found. Skipping...
# Processing Record 8 of Set 9 | fort nelson
# Processing Record 9 of Set 9 | san pedro de macoris
# Processing Record 10 of Set 9 | tilichiki
# Processing Record 11 of Set 9 | bonfim
# Processing Record 12 of Set 9 | coos bay
# Processing Record 13 of Set 9 | chumikan
# Processing Record 14 of Set 9 | cove
# Processing Record 15 of Set 9 | iranshahr
# Processing Record 16 of Set 9 | boguchany
# Processing Record 17 of Set 9 | makakilo city
# Processing Record 18 of Set 9 | bawku
# Processing Record 19 of Set 9 | irondequoit
# Processing Record 20 of Set 9 | avera
# Processing Record 21 of Set 9 | pasni
# Processing Record 22 of Set 9 | halifax
# Processing Record 23 of Set 9 | rocky mountain house
# Processing Record 24 of Set 9 | ancud
# Processing Record 25 of Set 9 | longyearbyen
# Processing Record 26 of Set 9 | rantauprapat
# Processing Record 27 of Set 9 | north platte
# Processing Record 28 of Set 9 | plesetsk
# Processing Record 29 of Set 9 | kaniama
# Processing Record 30 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 31 of Set 9 | cusuna
# Processing Record 32 of Set 9 | margate
# Processing Record 33 of Set 9 | mountrath
# Processing Record 34 of Set 9 | alice springs
# Processing Record 35 of Set 9 | bukama
# Processing Record 36 of Set 9 | spetsai
# City not found. Skipping...
# Processing Record 37 of Set 9 | tabou
# Processing Record 38 of Set 9 | villeneuve-les-avignon
# Processing Record 39 of Set 9 | westport
# Processing Record 40 of Set 9 | hue
# Processing Record 41 of Set 9 | narsaq
# Processing Record 42 of Set 9 | souillac
# Processing Record 43 of Set 9 | yumen
# Processing Record 44 of Set 9 | labuhan
# Processing Record 45 of Set 9 | luanda
# Processing Record 46 of Set 9 | pyapon
# Processing Record 47 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 48 of Set 9 | prince rupert
# Processing Record 49 of Set 9 | tura
# Processing Record 50 of Set 9 | magadan
# Processing Record 1 of Set 10 | kinston
# Processing Record 2 of Set 10 | avanigadda
# Processing Record 3 of Set 10 | salym
# Processing Record 4 of Set 10 | magdagachi
# Processing Record 5 of Set 10 | okhotsk
# Processing Record 6 of Set 10 | port augusta
# Processing Record 7 of Set 10 | synya
# Processing Record 8 of Set 10 | lucea
# Processing Record 9 of Set 10 | shambu
# Processing Record 10 of Set 10 | necochea
# Processing Record 11 of Set 10 | maldonado
# Processing Record 12 of Set 10 | agropoli
# Processing Record 13 of Set 10 | matara
# Processing Record 14 of Set 10 | kununurra
# Processing Record 15 of Set 10 | taoudenni
# Processing Record 16 of Set 10 | tual
# Processing Record 17 of Set 10 | ulkan
# Processing Record 18 of Set 10 | semey
# Processing Record 19 of Set 10 | muros
# Processing Record 20 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 10 | mwene-ditu
# Processing Record 22 of Set 10 | kudahuvadhoo
# Processing Record 23 of Set 10 | dianopolis
# City not found. Skipping...
# Processing Record 24 of Set 10 | slobodskoy
# Processing Record 25 of Set 10 | vila
# Processing Record 26 of Set 10 | denpasar
# Processing Record 27 of Set 10 | tambul
# City not found. Skipping...
# Processing Record 28 of Set 10 | poyarkovo
# Processing Record 29 of Set 10 | santa cruz del sur
# Processing Record 30 of Set 10 | uzunovo
# Processing Record 31 of Set 10 | cross lanes
# Processing Record 32 of Set 10 | palana
# Processing Record 33 of Set 10 | falkoping
# City not found. Skipping...
# Processing Record 34 of Set 10 | hinton
# Processing Record 35 of Set 10 | san francisco
# Processing Record 36 of Set 10 | opuwo
# Processing Record 37 of Set 10 | cherskiy
# Processing Record 38 of Set 10 | piranshahr
# Processing Record 39 of Set 10 | staroaleyskoye
# Processing Record 40 of Set 10 | tessalit
# Processing Record 41 of Set 10 | daru
# Processing Record 42 of Set 10 | kungurtug
# Processing Record 43 of Set 10 | sturgis
# Processing Record 44 of Set 10 | vestmannaeyjar
# Processing Record 45 of Set 10 | lixourion
# Processing Record 46 of Set 10 | palmer
# Processing Record 47 of Set 10 | svetlogorsk
# Processing Record 48 of Set 10 | iwanai
# Processing Record 49 of Set 10 | jinchengjiang
# City not found. Skipping...
# Processing Record 50 of Set 10 | monte alegre
# Processing Record 1 of Set 11 | yenagoa
# Processing Record 2 of Set 11 | honolulu
# Processing Record 3 of Set 11 | wanning
# Processing Record 4 of Set 11 | fernley
# Processing Record 5 of Set 11 | povoa de varzim
# Processing Record 6 of Set 11 | lenauheim
# Processing Record 7 of Set 11 | reconquista
# Processing Record 8 of Set 11 | along
# Processing Record 9 of Set 11 | duz
# City not found. Skipping...
# Processing Record 10 of Set 11 | bayir
# Processing Record 11 of Set 11 | boende
# Processing Record 12 of Set 11 | sedelnikovo
# City not found. Skipping...
# Processing Record 13 of Set 11 | marsabit
# Processing Record 14 of Set 11 | xiongyue
# Processing Record 15 of Set 11 | iracoubo
# Processing Record 16 of Set 11 | codrington
# Processing Record 17 of Set 11 | marzuq
# Processing Record 18 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 19 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 20 of Set 11 | lahij
# Processing Record 21 of Set 11 | pisco
# Processing Record 22 of Set 11 | tortoli
# Processing Record 23 of Set 11 | taltal
# Processing Record 24 of Set 11 | alihe
# Processing Record 25 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 11 | oranjestad
# Processing Record 27 of Set 11 | batsfjord
# Processing Record 28 of Set 11 | cine
# Processing Record 29 of Set 11 | goure
# Processing Record 30 of Set 11 | dwarka
# Processing Record 31 of Set 11 | klaksvik
# Processing Record 32 of Set 11 | araceli
# Processing Record 33 of Set 11 | kamenka
# Processing Record 34 of Set 11 | yuzhnyy
# Processing Record 35 of Set 11 | deep river
# Processing Record 36 of Set 11 | ornskoldsvik
# Processing Record 37 of Set 11 | zhigansk
# Processing Record 38 of Set 11 | sur
# Processing Record 39 of Set 11 | yatou
# Processing Record 40 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 41 of Set 11 | umm lajj
# Processing Record 42 of Set 11 | aktash
# Processing Record 43 of Set 11 | peruibe
# Processing Record 44 of Set 11 | ust-tsilma
# Processing Record 45 of Set 11 | melbu
# Processing Record 46 of Set 11 | nelson bay
# Processing Record 47 of Set 11 | upata
# Processing Record 48 of Set 11 | eganville
# Processing Record 49 of Set 11 | yar-sale
# Processing Record 50 of Set 11 | fort-shevchenko
# Processing Record 1 of Set 12 | roald
# Processing Record 2 of Set 12 | nichinan
# Processing Record 3 of Set 12 | general cepeda
# Processing Record 4 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 5 of Set 12 | uige
# Processing Record 6 of Set 12 | kursavka
# Processing Record 7 of Set 12 | timra
# Processing Record 8 of Set 12 | gwadar
# Processing Record 9 of Set 12 | cap malheureux
# Processing Record 10 of Set 12 | macamic
# Processing Record 11 of Set 12 | sao miguel do araguaia
# Processing Record 12 of Set 12 | visnes
# Processing Record 13 of Set 12 | zaqatala
# Processing Record 14 of Set 12 | talcahuano
# Processing Record 15 of Set 12 | ilinskiy
# Processing Record 16 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 17 of Set 12 | port lincoln
# Processing Record 18 of Set 12 | mombetsu
# Processing Record 19 of Set 12 | menasha
# Processing Record 20 of Set 12 | bafilo
# Processing Record 21 of Set 12 | galle
# Processing Record 22 of Set 12 | marsa matruh
# Processing Record 23 of Set 12 | sapapalii
# City not found. Skipping...
# Processing Record 24 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 25 of Set 12 | todos santos
# Processing Record 26 of Set 12 | bathsheba
# Processing Record 27 of Set 12 | bilgi
# Processing Record 28 of Set 12 | voh
# Processing Record 29 of Set 12 | ust-kuyga
# Processing Record 30 of Set 12 | verkhnevilyuysk
# Processing Record 31 of Set 12 | saint-joseph
# Processing Record 32 of Set 12 | rapid city
# Processing Record 33 of Set 12 | inuvik
# Processing Record 34 of Set 12 | allapalli
# Processing Record 35 of Set 12 | mandalgovi
# Processing Record 36 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 37 of Set 12 | rayong
# Processing Record 38 of Set 12 | marathon
# Processing Record 39 of Set 12 | mizdah
# Processing Record 40 of Set 12 | takaka
# Processing Record 41 of Set 12 | mildura
# Processing Record 42 of Set 12 | namatanai
# Processing Record 43 of Set 12 | nagato
# Processing Record 44 of Set 12 | sembe
# Processing Record 45 of Set 12 | imbituba
# Processing Record 46 of Set 12 | pemangkat
# Processing Record 47 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 12 | bonthe
# Processing Record 49 of Set 12 | chapais
# Processing Record 50 of Set 12 | sobolevo
# Processing Record 1 of Set 13 | nantucket
# Processing Record 2 of Set 13 | kurchum
# Processing Record 3 of Set 13 | guerrero negro
# Processing Record 4 of Set 13 | tunduru
# City not found. Skipping...
# Processing Record 5 of Set 13 | jitra
# Processing Record 6 of Set 13 | dongkan
# Processing Record 7 of Set 13 | mlimba
# Processing Record 8 of Set 13 | elko
# Processing Record 9 of Set 13 | uyutne
# Processing Record 10 of Set 13 | barranca
# Processing Record 11 of Set 13 | urucuca
# Processing Record 12 of Set 13 | karpogory
# Processing Record 13 of Set 13 | moffat
# Processing Record 14 of Set 13 | formosa
# Processing Record 15 of Set 13 | armizonskoye
# Processing Record 16 of Set 13 | sampit
# Processing Record 17 of Set 13 | venice
# Processing Record 18 of Set 13 | dhone
# Processing Record 19 of Set 13 | tiarei
# Processing Record 20 of Set 13 | iskateley
# Processing Record 21 of Set 13 | tucuman
# Processing Record 22 of Set 13 | lulea
# Processing Record 23 of Set 13 | tambo
# Processing Record 24 of Set 13 | kuito
# Processing Record 25 of Set 13 | foso
# Processing Record 26 of Set 13 | payo
# Processing Record 27 of Set 13 | cockburn town
# Processing Record 28 of Set 13 | karasburg
# Processing Record 29 of Set 13 | beihai
# Processing Record 30 of Set 13 | sao joaquim
# Processing Record 31 of Set 13 | kaspiysk
# Processing Record 32 of Set 13 | shelopugino
# Processing Record 33 of Set 13 | zalishchyky
# Processing Record 34 of Set 13 | quang ngai
# Processing Record 35 of Set 13 | sar-e pul
# Processing Record 36 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 37 of Set 13 | baker city
# Processing Record 38 of Set 13 | kultuk
# Processing Record 39 of Set 13 | ahuimanu
# Processing Record 40 of Set 13 | verkhoyansk
# Processing Record 41 of Set 13 | komsomolskiy
# Processing Record 42 of Set 13 | berbera
# Processing Record 43 of Set 13 | deputatskiy
# Processing Record 44 of Set 13 | esfarayen
# Processing Record 45 of Set 13 | panzhihua
# Processing Record 46 of Set 13 | pangody
# Processing Record 47 of Set 13 | pamanukan
# Processing Record 48 of Set 13 | gambela
# Processing Record 49 of Set 13 | manado
# Processing Record 50 of Set 13 | sinegorye
# Processing Record 1 of Set 14 | bilibino
# Processing Record 2 of Set 14 | skibbereen
# Processing Record 3 of Set 14 | aklavik
# Processing Record 4 of Set 14 | karasjok
# Processing Record 5 of Set 14 | mansa
# Processing Record 6 of Set 14 | santa fe
# Processing Record 7 of Set 14 | aginskoye
# Processing Record 8 of Set 14 | kalianget
# Processing Record 9 of Set 14 | katima mulilo
# Processing Record 10 of Set 14 | yamada
# Processing Record 11 of Set 14 | abbeville
# Processing Record 12 of Set 14 | pachino
# Processing Record 13 of Set 14 | san jose
# Processing Record 14 of Set 14 | meulaboh
# Processing Record 15 of Set 14 | ajdabiya
# Processing Record 16 of Set 14 | rawson
# Processing Record 17 of Set 14 | winnemucca
# Processing Record 18 of Set 14 | praia
# Processing Record 19 of Set 14 | grindavik
# Processing Record 20 of Set 14 | catende
# Processing Record 21 of Set 14 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 14 | chicama
# Processing Record 23 of Set 14 | uyemskiy
# Processing Record 24 of Set 14 | kizukuri
# Processing Record 25 of Set 14 | berlevag
# Processing Record 26 of Set 14 | byron bay
# Processing Record 27 of Set 14 | madang
# Processing Record 28 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 29 of Set 14 | kaabong
# Processing Record 30 of Set 14 | araraquara
# Processing Record 31 of Set 14 | sakete
# Processing Record 32 of Set 14 | jibuti
# Processing Record 33 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 34 of Set 14 | lichuan
# Processing Record 35 of Set 14 | burgeo
# Processing Record 36 of Set 14 | south sioux city
# Processing Record 37 of Set 14 | pangkalanbuun
# Processing Record 38 of Set 14 | imeni zhelyabova
# Processing Record 39 of Set 14 | luderitz
# Processing Record 40 of Set 14 | sovetskiy
# Processing Record 41 of Set 14 | nakskov
# Processing Record 42 of Set 14 | westford
# Processing Record 43 of Set 14 | queenstown
# Processing Record 44 of Set 14 | los llanos de aridane
# Processing Record 45 of Set 14 | pringsewu
# Processing Record 46 of Set 14 | baculin
# Processing Record 47 of Set 14 | paamiut
# Processing Record 48 of Set 14 | nam tha
# City not found. Skipping...
# Processing Record 49 of Set 14 | cairns
# Processing Record 50 of Set 14 | akyab
# Processing Record 1 of Set 15 | beloha
# Processing Record 2 of Set 15 | la palma
# Processing Record 3 of Set 15 | roebourne
# Processing Record 4 of Set 15 | wanaka
# Processing Record 5 of Set 15 | manaure
# Processing Record 6 of Set 15 | yayva
# Processing Record 7 of Set 15 | eyl
# Processing Record 8 of Set 15 | torres
# Processing Record 9 of Set 15 | marsala
# Processing Record 10 of Set 15 | alekseyevsk
# Processing Record 11 of Set 15 | lyngseidet
# Processing Record 12 of Set 15 | asfi
# Processing Record 13 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 15 | santiago del estero
# Processing Record 15 of Set 15 | kalmar
# Processing Record 16 of Set 15 | iberia
# Processing Record 17 of Set 15 | leh
# Processing Record 18 of Set 15 | mathathane
# Processing Record 19 of Set 15 | mosquera
# Processing Record 20 of Set 15 | homer
# Processing Record 21 of Set 15 | mackay
# Processing Record 22 of Set 15 | petukhovo
# Processing Record 23 of Set 15 | tezu
# Processing Record 24 of Set 15 | manyana
# Processing Record 25 of Set 15 | itaituba
# Processing Record 26 of Set 15 | andra
# Processing Record 27 of Set 15 | ukiah
# Processing Record 28 of Set 15 | makhachkala
# Processing Record 29 of Set 15 | trincomalee
# Processing Record 30 of Set 15 | gimli
# Processing Record 31 of Set 15 | palimbang
# Processing Record 32 of Set 15 | banda aceh
# Processing Record 33 of Set 15 | orlik
# Processing Record 34 of Set 15 | quelimane
# Processing Record 35 of Set 15 | polis
# Processing Record 36 of Set 15 | noumea
# Processing Record 37 of Set 15 | birjand
# Processing Record 38 of Set 15 | kotma
# Processing Record 39 of Set 15 | benguela
# Processing Record 40 of Set 15 | neuquen
# Processing Record 41 of Set 15 | krasnoselkup
# Processing Record 42 of Set 15 | smithers
# Processing Record 43 of Set 15 | tara
# Processing Record 44 of Set 15 | roura
# Processing Record 45 of Set 15 | talawdi
# City not found. Skipping...
# Processing Record 46 of Set 15 | brae
# Processing Record 47 of Set 15 | san roque
# Processing Record 48 of Set 15 | isla vista
# Processing Record 49 of Set 15 | enshi
# Processing Record 50 of Set 15 | kushalgarh
# Processing Record 1 of Set 16 | antropovo
# Processing Record 2 of Set 16 | dhidhdhoo
# Processing Record 3 of Set 16 | saint austell
# Processing Record 4 of Set 16 | dmytrivka
# Processing Record 5 of Set 16 | collie
# Processing Record 6 of Set 16 | pandharpur
# Processing Record 7 of Set 16 | chekmagush
# Processing Record 8 of Set 16 | hibbing
# Processing Record 9 of Set 16 | xichang
# Processing Record 10 of Set 16 | yabelo
# Processing Record 11 of Set 16 | santa lucia
# Processing Record 12 of Set 16 | sannicandro di bari
# Processing Record 13 of Set 16 | sal rei
# Processing Record 14 of Set 16 | kralendijk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
print(len(city_data))
# Out:
# 696

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Pacific Grove  36.6177 -121.9166     64.54        76         100
# 1       Freeport  40.6576  -73.5832     59.97        74         100
# 2        Mataura -46.1927  168.8643     47.48        99          37
# 3          Kapaa  22.0752 -159.3190     76.10        92         100
# 4      Busselton -33.6500  115.3333     48.22        78           3
# 5          Adrar  20.5022  -10.0711     97.36        19          39
# 6            Ola  59.5833  151.2833     32.14        58          90
# 7           Zhob  31.3411   69.4481     73.54        40           0
# 8        Ushuaia -54.8000  -68.3000     46.06        46           0
# 9         Hasaki  35.7333  140.8333     66.60        60          83
#
#    Wind Speed Country Current Description
# 0        4.00      US     overcast clouds
# 1       21.85      US          light rain
# 2        2.91      NZ    scattered clouds
# 3       21.85      US                mist
# 4       12.57      AU           clear sky
# 5        8.37      MR    scattered clouds
# 6        8.28      RU     overcast clouds
# 7        3.22      PK           clear sky
# 8        5.75      AR           clear sky
# 9        4.74      JP       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", 
                    "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)

### This appears to have been the original order of the columns.
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Pacific Grove      US  36.6177 -121.9166     64.54        76         100
# 1       Freeport      US  40.6576  -73.5832     59.97        74         100
# 2        Mataura      NZ -46.1927  168.8643     47.48        99          37
# 3          Kapaa      US  22.0752 -159.3190     76.10        92         100
# 4      Busselton      AU -33.6500  115.3333     48.22        78           3
# 5          Adrar      MR  20.5022  -10.0711     97.36        19          39
# 6            Ola      RU  59.5833  151.2833     32.14        58          90
# 7           Zhob      PK  31.3411   69.4481     73.54        40           0
# 8        Ushuaia      AR -54.8000  -68.3000     46.06        46           0
# 9         Hasaki      JP  35.7333  140.8333     66.60        60          83
#
#    Wind Speed Current Description
# 0        4.00     overcast clouds
# 1       21.85          light rain
# 2        2.91    scattered clouds
# 3       21.85                mist
# 4       12.57           clear sky
# 5        8.37    scattered clouds
# 6        8.28     overcast clouds
# 7        3.22           clear sky
# 8        5.75           clear sky
# 9        4.74       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file)
